# %%
import pandas as pd

train_df = pd.read_csv('../data/train.csv', delimiter=';')
test_df = pd.read_csv('../data/test.csv', delimiter=';')
train_df.head()
# Out:
#    ID  id_season      aggregated_family   family  \
# 0   1         86  Dresses and jumpsuits  Dresses
# 1   1         86  Dresses and jumpsuits  Dresses
# 2   1         86  Dresses and jumpsuits  Dresses
# 3   1         86  Dresses and jumpsuits  Dresses
# 4   1         86  Dresses and jumpsuits  Dresses
#
#                               category fabric color_name  color_rgb  \
# 0  Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 1  Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 2  Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 3  Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 4  Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
#
#                                      image_embedding length_type  ...  \
# 0  0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 1  0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 2  0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 3  0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 4  0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
#
#   life_cycle_length num_stores num_sizes has_plus_sizes  price  year  \
# 0                12        152         5          False  35.99  2023
# 1                12        152         5          False  35.99  2023
# 2                12        152         5          False  35.99  2023
# 3                12        152         5          False  35.99  2023
# 4                12        152         5          False  35.99  2023
#
#   num_week_iso weekly_sales weekly_demand Production
# 0            1           66            69       4556
# 1            2          112           112       4556
# 2            3          135           135       4556
# 3            4           99            99       4556
# 4            5           74            74       4556
#
# [5 rows x 33 columns]

# %%
test_df.head()
# Out:
#     ID  id_season       aggregated_family     family  \
# 0   90         90       Skirts and shorts     Shorts
# 1   16         90     Jackets and Blazers    Jackets
# 2   65         90  Sweaters and Cardigans  Cardigans
# 3  138         90   Dresses and jumpsuits    Dresses
# 4  166         90       Swim and intimate   Swimwear
#
#                               category    fabric color_name    color_rgb  \
# 0                              Bottoms     WOVEN     BLANCO  245,244,238
# 1                            Outerwear     WOVEN     MARRON   129,105,81
# 2                                 Tops  CIRCULAR       GRIS  145,145,144
# 3  Dresses, jumpsuits and Complete set     WOVEN      ARENA  219,207,189
# 4        Accesories, Swim and Intimate  CIRCULAR       ROJO    189,22,62
#
#                                      image_embedding length_type  ...  \
# 0  -0.12171847,-0.25323686,0.6839907,-0.60686946,...       Short  ...
# 1  -0.2704233,-1.1392772,1.2337782,-0.64782524,0....       Short  ...
# 2  -0.16349873,0.10306308,1.1780332,-0.6578121,0....    Standard  ...
# 3  0.13487932,0.004863858,-0.52593106,-0.8941919,...        Long  ...
# 4  0.08456349,0.06271024,-0.11037013,-0.6067481,0...         NaN  ...
#
#   life_cycle_length num_stores num_sizes has_plus_sizes  price  Unnamed: 28  \
# 0                 6        118         5          False  29.99          NaN
# 1                10        456         7          False  69.99          NaN
# 2                 8        542         7          False  22.99          NaN
# 3                 8         87         5          False  89.99          NaN
# 4                16         38         5          False  17.99          NaN
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 33 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2250 entries, 0 to 2249
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  2250 non-null   int64
#  1   id_season           2250 non-null   int64
#  2   aggregated_family   2250 non-null   object
#  3   family              2250 non-null   object
#  4   category            2250 non-null   object
#  5   fabric              2250 non-null   object
#  6   color_name          2250 non-null   object
#  7   color_rgb           2250 non-null   object
#  8   image_embedding     2250 non-null   object
#  9   length_type         1868 non-null   object
#  10  silhouette_type     1771 non-null   object
#  11  waist_type          450 non-null    object
#  12  neck_lapel_type     1387 non-null   object
#  13  sleeve_length_type  1336 non-null   object
#  14  heel_shape_type     0 non-null      float64
#  15  toecap_type         0 non-null      float64
#  16  woven_structure     1382 non-null   object
#  17  knit_structure      395 non-null    object
#  18  print_type          2247 non-null   object
#  19  archetype           200 non-null    object
#  20  moment              2250 non-null   object
#  21  phase_in            2250 non-null   object
#  22  phase_out           2250 non-null   object
#  23  life_cycle_length   2250 non-null   int64
#  24  num_stores          2250 non-null   int64
#  25  num_sizes           2250 non-null   int64
#  26  has_plus_sizes      2250 non-null   bool
#  27  price               2250 non-null   float64
#  28  Unnamed: 28         0 non-null      float64
#  29  Unnamed: 29         0 non-null      float64
#  30  Unnamed: 30         0 non-null      float64
#  31  Unnamed: 31         0 non-null      float64
#  32  Unnamed: 32         0 non-null      float64
# dtypes: bool(1), float64(8), int64(5), object(19)
# memory usage: 564.8+ KB

# %%
# count number of rows with weekly_sales == -1706
train_df[train_df['weekly_demand'] == -1496].shape[0]
# Out:
# 1

# %%
train_df[train_df['ID'] == 1]
# Out:
#     ID  id_season      aggregated_family   family  \
# 0    1         86  Dresses and jumpsuits  Dresses
# 1    1         86  Dresses and jumpsuits  Dresses
# 2    1         86  Dresses and jumpsuits  Dresses
# 3    1         86  Dresses and jumpsuits  Dresses
# 4    1         86  Dresses and jumpsuits  Dresses
# 5    1         86  Dresses and jumpsuits  Dresses
# 6    1         86  Dresses and jumpsuits  Dresses
# 7    1         86  Dresses and jumpsuits  Dresses
# 8    1         86  Dresses and jumpsuits  Dresses
# 9    1         86  Dresses and jumpsuits  Dresses
# 10   1         86  Dresses and jumpsuits  Dresses
# 11   1         86  Dresses and jumpsuits  Dresses
#
#                                category fabric color_name  color_rgb  \
# 0   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 1   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 2   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 3   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 4   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 5   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 6   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 7   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 8   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 9   Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 10  Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
# 11  Dresses, jumpsuits and Complete set  WOVEN   AMARILLO  255,215,0
#
#                                       image_embedding length_type  ...  \
# 0   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 1   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 2   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 3   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 4   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 5   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 6   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 7   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 8   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 9   0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 10  0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
# 11  0.072266474,-0.12752205,0.6080948,-1.2579741,-...        Long  ...
#
#    life_cycle_length num_stores num_sizes has_plus_sizes  price  year  \
# 0                 12        152         5          False  35.99  2023
# 1                 12        152         5          False  35.99  2023
# 2                 12        152         5          False  35.99  2023
# 3                 12        152         5          False  35.99  2023
# 4                 12        152         5          False  35.99  2023
# 5                 12        152         5          False  35.99  2023
# 6                 12        152         5          False  35.99  2023
# 7                 12        152         5          False  35.99  2023
# 8                 12        152         5          False  35.99  2023
# 9                 12        152         5          False  35.99  2023
# 10                12        152         5          False  35.99  2023
# 11                12        152         5          False  35.99  2023
#
#    num_week_iso weekly_sales weekly_demand Production
# 0             1           66            69       4556
# 1             2          112           112       4556
# 2             3          135           135       4556
# 3             4           99            99       4556
# 4             5           74            74       4556
# 5             6           62            62       4556
# 6             7           45            45       4556
# 7             8           38            38       4556
# 8             9           34            34       4556
# 9            10           53            53       4556
# 10           11           34            35       4556
# 11           12           50            50       4556
#
# [12 rows x 33 columns]

# %%
# check how many ids are the same and how many different in train and test
train_ids = train_df['ID'].unique()
test_ids = test_df['ID'].unique()
len(train_ids)
len(test_ids)
# check how many ids are in both train and test
len(set(train_ids) & set(test_ids))
# check how many ids are in train but not in test
len(set(train_ids) - set(test_ids))
# check how many ids are in test but not in train
len(set(test_ids) - set(train_ids))
# check how many ids are in train and test
len(set(train_ids) & set(test_ids))

# %%
from ydata_profiling import ProfileReport
import pandas as pd
import numpy as np

df = pd.read_csv('../data/test.csv', delimiter=';')

# Exclude text columns to avoid wordcloud errors inside ydata_profiling
non_text_cols = df.select_dtypes(exclude=['object']).columns

# %%
profile = ProfileReport(df[non_text_cols], title="MANGO-test (no text)", plot={"wordcloud": False})

# %%
# save to html
profile.to_file("../data/test_report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
